# %%
import aifeynman

pathdir = "example_data/"
filename = "example1.txt"
BF_try_time = 60
BF_ops_file_type = "14ops.txt"
polyfit_deg = 3
NN_epochs = 500
vars_name = ['x1', 'x2', 'y1', 'y2', 'd']
test_percentage = 20

aifeynman.run_aifeynman(pathdir, filename, BF_try_time= BF_try_time, BF_ops_file_type=BF_ops_file_type, polyfit_deg=polyfit_deg, NN_epochs=NN_epochs, vars_name=vars_name, test_percentage=test_percentage)
# Out:
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve example_data/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve example_data/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_log/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_log/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sqrt/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sqrt/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/example1.txt_dim_red_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/example1.txt_dim_red_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Training a NN on the data...
#
# NN loss:  (tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>), SimpleNet(
#   (linear1): Linear(in_features=3, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=64, bias=True)
#   (linear5): Linear(in_features=64, out_features=1, bias=True)
# ))
#
# Checking for symmetries...
#
# Checking for separabilities...
#
# Checking for compositionality...
# Trying to solve mysteries with brute force...
# Trying to solve results/gradients_comp_example1.txt_dim_red_train.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 vars_name = ['x1', 'x2', 'y1', 'y2', 'd']
#      10 test_percentage = 20
# ---> 12 aifeynman.run_aifeynman(pathdir, filename, BF_try_time= BF_try_time, BF_ops_file_type=BF_ops_file_type, polyfit_deg=polyfit_deg, NN_epochs=NN_epochs, vars_name=vars_name, test_percentage=test_percentage)
#
# File ~/dev/AI-Feynman/aifeynman/S_run_aifeynman.py:275, in run_aifeynman(pathdir, filename, BF_try_time, BF_ops_file_type, polyfit_deg, NN_epochs, vars_name, test_percentage)
#     273 PA = ParetoSet()
#     274 # Run the code on the train data
# --> 275 PA = run_AI_all(pathdir,filename+"_train",BF_try_time,BF_ops_file_type, polyfit_deg, NN_epochs, PA=PA)
#     276 PA_list = PA.get_pareto_points()
#     278 '''
#     279 # Run bf snap on the resulted equations
#     280 for i in range(len(PA_list)):
#    (...)
#     285 PA_list = PA.get_pareto_points()
#     286 '''
#
# File ~/dev/AI-Feynman/aifeynman/S_run_aifeynman.py:126, in run_AI_all(pathdir, filename, BF_try_time, BF_ops_file_type, polyfit_deg, NN_epochs, PA)
#     124 for qqqq in range(1):
#     125     brute_force_comp("results/","gradients_comp_%s.txt" %filename,600,"14ops.txt")
# --> 126     bf_all_output = np.loadtxt("results_comp.dat", dtype="str")
#     127     for bf_i in range(len(bf_all_output)):
#     128         idx_comp_temp = 0
#
# File ~/dev/feyn/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1380, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1377 if isinstance(delimiter, bytes):
#    1378     delimiter = delimiter.decode('latin1')
# -> 1380 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1381             converters=converters, skiplines=skiprows, usecols=usecols,
#    1382             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1383             max_rows=max_rows, quote=quotechar)
#    1385 return arr
#
# File ~/dev/feyn/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     995     fname = os.fspath(fname)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#     999         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/dev/feyn/lib/python3.10/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/dev/feyn/lib/python3.10/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: results_comp.dat not found.

# %%
import os
os.getcwd()
# Out:
# '/home/jleonard/dev/AI-Feynman'
